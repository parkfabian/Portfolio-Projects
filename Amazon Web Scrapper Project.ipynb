# %%
#Import libraries

from bs4 import BeautifulSoup
import requests
import smtplib
import time
import datetime
import csv
import pandas as pd

# %%
# Connect to Website
URL = 'https://www.ebay.com/itm/384127472200?hash=item596fc81248:g:kCoAAOSwF05gjBu0'

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36"}


page = requests.get(URL, headers= headers)

# %%
soup1 = BeautifulSoup(page.content, 'html.parser')


soup2 = BeautifulSoup(soup1.prettify(),'html.parser')
print(soup2)
# Out:
# <!DOCTYPE html>
#
# <html lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <link href="//i.ebayimg.com" rel="dns-prefetch"/>
# <link href="//thumbs.ebaystatic.com" rel="dns-prefetch"/>
# <link href="//vi.vipr.ebaydesc.com" rel="dns-prefetch"/>
# <link href="//p.ebaystatic.com" rel="dns-prefetch"/>
# <link href="//q.ebaystatic.com" rel="dns-prefetch"/>
# <link href="//pics.ebaystatic.com" rel="dns-prefetch"/>
# <link href="//ir.ebaystatic.com" rel="dns-prefetch"/>
# <link href="//srx.main.ebayrtm.com" rel="dns-prefetch"/>
# <link href="//rover.ebay.com" rel="dns-prefetch"/>
# <link href="//reco.ebay.com" rel="dns-prefetch"/>
# <!--  fix for IE freezing.  -->
# <style type="text/css">
#    body #Body .btn, body #Body c-std {
# filter:none;
# -ms-filter: "progid:DXImageTransform.Microsoft.gradient(startColorstr='#0079bc',endColorstr='#00509d')";
# }
#   </style>
# <meta name="viewport"/>
# <meta content="main" name="layout"/>
# <!-- Use ?ForceSiteSpeedGauge=true for forcing -->
# <link href="//secureir.ebaystatic.com" rel="dns-prefetch"/>
# <link href="//i.ebayimg.com" rel="dns-prefetch"/>
# <meta content="unsafe-url" name="referrer"/>
# <meta content="Data Statistics Math Computer Science Shirt Analyst T-Shirt  | eBay" property="og:title"/>
# <meta content="34E98E6F27109BE1A9DCF19658EEEE33" name="msvalidate.01"/>
# <link href="https://ir.ebaystatic.com" rel="preconnect"/>
# <meta content="@eBay" name="twitter:site"/>
# <meta content="Preshrunk jersey knit." property="og:description"/>
# <meta content="ebay-objects:item" property="og:type"/>
# <link href="https://www.ebay.com/itm/384127472200" rel="canonical"/>
# <meta content="max-snippet:-1, max-image-preview:large" name="robots"/>
# <meta content="8kHr3jd3Z43q1ovwo0KVgo_NZKIEMjthBxti8m8fYTg" name="google-site-verification"/>
# <meta content="en-US" http-equiv="content-language"/>
# <meta content="eBay" property="og:site_name"/>
# <meta content="6e11485a66d91eff" name="yandex-verification"/>
# <meta content="acf32e2a69cbc2b0" name="y_key"/>
# <link href="android-app://com.ebay.mobile/ebay/link/?nav=item.view&amp;id=384127472200&amp;referrer=http%3A%2F%2Frover.ebay.com%2Froverns%2F1%2F711-13271-9788-0%3Fmpcl%3Dhttp%253A%252F%252Fwww.ebay.com%252Fitm%252F384127472200" rel="alternate"/>
# <link href="https://i.ebayimg.com" rel="preconnect"/>
# <meta content="102628213125203" property="fb:app_id"/>
# <meta content="Preshrunk jersey knit." name="description"/>
# <title>
#        Data Statistics Math Computer Science Shirt Analyst T-Shirt  | eBay
#       </title>
# <meta content="https://i.ebayimg.com/images/g/kCoAAOSwF05gjBu0/s-l400.jpg" property="og:image"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="Preshrunk jersey knit." name="twitter:description"/>
# <meta content="https://www.ebay.com/itm/384127472200" property="og:url"/>
# <meta content="Data Statistics Math Computer Science Shirt Analyst T-Shirt" name="twitter:title"/>
# <meta content="https://i.ebayimg.com/images/g/kCoAAOSwF05gjBu0/s-l400.jpg" name="twitter:image"/>
# <!-- NGMARS SIGNATURE -->
# <!--[if IE]><link/><![endif]-->
# <!--[if lt IE 8]>
# 		<![endif]-->
# <!-- adding lens js -->
# <link href="https://ir.ebaystatic.com/rs/v/wj5me5fcje30plvskbdshogdfik.css" rel="stylesheet" type="text/css">
# <link href="https://ir.ebaystatic.com/rs/v/x4f5pfotku33fegxfdaz1gq5sqp.css?proc=DU:N" rel="stylesheet" type="text/css">
# <link href="https://ir.ebaystatic.com/rs/v/h5wqw0b3au53jn1uwcfoqddy1me.css" rel="stylesheet" type="text/css">
# <style type="text/css">
#        body .is.vi-ppc-main .mm-dp {
# width:35%;
# }
#
# #vi-snippet-description-main.u-padB20 {
#     padding-top:10px;
#     float:left;
# }
#
# .vi-descsnpt-feedbacklnk {
#     position: relative;
#     top: -20px;
#     width: 500px;
#     margin-left: 250px;
# }
#
# .asqMain {
#     clear:both;
# }
#
# div#bsi-c {
# clear: both;
# }
# .vi-pco-bboxtxt-Ins * {
# 	font-weight: normal !important;
# 	color: #0654ba !important;
# }
# div.addonyes{ background: url('//ir.ebaystatic.com/cr/v/c1/addonwrty.png') no-repeat 0 -54px; background-size: 16px; }
# div.addonno{ background: url('//ir.ebaystatic.com/cr/v/c1/addonwrty.png') no-repeat 0 -72px; background-size: 16px; }
# .adninc{width:620px}.imgtitle{background-color:#fff;height:76px;padding-top:16px}.adnimg{float:left;padding:0 16px 0 24px;height:60px;width:60px;line-height:60px}.adnlogoimg{max-width:60px;max-height:60px;vertical-align:middle}#adndesctbl{margin-bottom:10px}.adnlabel{font-size:17px;vertical-align:middle;font-family:HelveticaNeue,Helvetica Neue,Helvetica,Arial,sans-serif;font-weight:500;font-stretch:normal;color:#5ba71b;padding-top:10px}.adntitle{font-size:13px;vertical-align:middle;font-family:HelveticaNeue,Helvetica Neue,Helvetica,Arial,sans-serif;font-weight:500;font-stretch:normal;color:#333;padding-top:8px}.adnactions{padding-top:24px}.adnlrnmore{display:block;float:left;font-size:14px;color:#00489f;padding:16px 0 0 16px;text-decoration:none;outline:0 none!important;font-weight:400}.addonBtn{float:right}.adndesclbl{font-family:HelveticaNeue,Helvetica Neue,Helvetica,Arial,sans-serif;font-size:20px;font-weight:400;font-style:normal;font-stretch:normal;color:#555;padding:0 0 16px 16px}.adndesc{border-top:solid 1px #ddd;padding:24px;background-color:#f6f6f6}.addondescdetails{border-collapse:collapse;border:1px solid #DDD;background-color:#fff;border-radius:5px}.wrttitle{padding:16px;font-family:HelveticaNeue,Helvetica Neue,Helvetica,Arial,sans-serif;font-size:15px;font-weight:500;font-style:normal;font-stretch:normal;text-align:left;color:#333}.addontr{height:25px;vertical-align:middle}.addyesno{padding:6px 12px 6px 16px;width:16px}.addonyes{background:url(//ir.ebaystatic.com/cr/v/c1/addonwrty.png) no-repeat 0 -54px;height:16px;width:16px;background-size:16px}.addonno{background:url(//ir.ebaystatic.com/cr/v/c1/addonwrty.png) no-repeat 0 -72px;height:16px;width:16px;background-size:16px}.addondesc{font-size:13px;line-height:15px;font-family:HelveticaNeue,Helvetica Neue,Helvetica,Arial,sans-serif;width:528px;padding:6px 12px 6px 0}.addonbtn{padding:.5em 1.2em;border:1px solid transparent;border-radius:3px;vertical-align:baseline;text-align:center;text-decoration:none;white-space:nowrap;font-weight:500;font-size:16px;cursor:pointer;zoom:1;display:inline-block;*display:inline;width:129px;font-family:HelveticaNeue,Helvetica Neue,Helvetica,Arial,sans-serif}.adnclr{clear:both}.addonbtn{padding:.5em 1.2em;border:1px solid transparent;border-radius:3px;vertical-align:baseline;text-align:center;text-decoration:none;white-space:nowrap;font-weight:500;font-size:16px;cursor:pointer;zoom:1;display:inline-block;*display:inline;width:129px;font-family:HelveticaNeue,Helvetica Neue,Helvetica,Arial,sans-serif}.addonbtn:hover{background-color:#eee;background-position:0 -15px;-webkit-box-shadow:0 0 0 rgba(0,0,0,.2);-moz-box-shadow:0 0 0 rgba(0,0,0,.2);box-shadow:0 0 0 rgba(0,0,0,.2);text-decoration:none;-moz-transition:background-position .1s linear 0}.addonbtn:active{position:relative;top:1px}.addonaddplan{background:#00509d;background:-webkit-gradient(linear,left top,left bottom,from(#0079bc),to(#00509d));background:-moz-linear-gradient(top,#0079bc,#00509d);text-decoration:none;filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#0079bc',endColorstr='#00509d');color:#fff;margin-right:16px;font-family:HelveticaNeue,Helvetica Neue,Helvetica,Arial,sans-serif}.addonaddplan:hover,.addonaddplan:focus,.addonaddplan:active{background:#00509d;filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#00509d',endColorstr='#00509d')}.addonnothx{border:1px solid #ddd;background:#f8f8f8;background:-webkit-gradient(linear,left top,left bottom,from(#fefefe),to(#f8f8f8));background:-moz-linear-gradient(top,#fefefe,#f8f8f8);text-decoration:none;filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#fefefe',endColorstr='#f8f8f8');color:#0654ba;margin-right:16px;font-family:HelveticaNeue,Helvetica Neue,Helvetica,Arial,sans-serif}.addonnothx:hover,.addonnothx:focus,.addonnothx:active{border:1px solid #aaa;background:#fafafa}.ui-hlp-hidden{width:0;height:0;z-index:-1;overflow:hidden;line-height:0;position:absolute}.outline{outline:0 no ...
# .similar-items-panel .similar-items-title {font-family: "Helvetica neue",Helvetica,Verdana,Sans-serif !important;}
# #Body .app-mtp-theme-tabs * {font-family: "Helvetica neue",Helvetica,Verdana,Sans-serif}
# #Body .theme-details * {font-family: "Helvetica neue",Helvetica,Verdana,Sans-serif}
# h1#ProductTitle {font-family: "Helvetica neue",Helvetica,Verdana,Sans-serif}
#       </style>
# <style type="text/css">
#        html a:link{
# 					color: #0654ba;
# 				}
# 				ul#bc a:link{
# 					color: #0654ba;
# 				}
# 				.mbg a:link{
# 					color: #0654ba !important;
# 				}
# 				.mbg-l a:link{
# 					color: #0654ba !important;
# 				}
# 				#Body .nav-tabs-m a:link{
# 					color: #0654ba;
# 				}
#       </style>
# <link href="https://ir.ebaystatic.com/rs/c/vimoduleapi-y-FC1WWX.css" rel="stylesheet" type="text/css"/>
# </link>
# </link>
# </link>
# </head>
# <body class="vi-contv2 lhdr-ie- vi-hd-ops vi-wide-watch-btn vi-ds3-global vi-bb-flex label-right-align vi-bb-btnclr1 vi-ds6 vi-bb-r-btn vi-white-spacing vi-rounded-btns vi-long-cta">
# <div id="Head">
# </div>
# <div class="sz940" id="Body" itemscope="itemscope" itemtype="https://schema.org/Product">
# <div id="maskDiv">
# </div>
# <div id="TopPanelDF">
# <div id="Top">
# <div class="" id="TopPanel">
# <style>
#        .gh-hide-if-nocss{display:none;}.gh-ar-hdn{color:#fff}
#       </style>
# <div class="gh-acc-exp-div gh-hide-if-nocss">
# <a class="gh-acc-a" href="#mainContent" id="gh-hdn-stm">
#         Skip to main content
#        </a>
# </div>
# <!--[if lt IE 9]><div id="gh" role="banner" class="gh-IE8 gh-flex gh-pre-js gh-w "><![endif]-->
# <!--[if (gte IE 9)|!(IE)]><!-->
# <header class="gh-ui-6-5 gh-flex gh-pre-js gh-w gh-sch-prom" data-treatment="" id="gh" role="banner">
# <!--<![endif]-->
# <table class="gh-tbl" role="presentation">
# <tbody>
# <tr>
# <td class="gh-td">
# <!--[if lt IE 9]><a href="https://www.ebay.com/" _sp="m570.l2586" id="gh-la"><img width=117 height=120 style='clip:rect(47px, 118px, 95px, 0px); position:absolute; top:-47px;left:0' alt="eBay Logo" src="https://ir.ebaystatic.com/rs/v/apstidvcvu5pxlbxkphrrdo5iqv.png" id="gh-logo"></a><![endif]-->
# <!--[if (gte IE 9)|!(IE)]><!-->
# <a _sp="m570.l2586" href="https://www.ebay.com/" id="gh-la">
# <img alt="eBay Logo" height="200" id="gh-logo" src="https://ir.ebaystatic.com/rs/v/fxxj3ttftm5ltcqnto1o4baovyl.png" style="clip:rect(47px, 118px, 95px, 0px); position:absolute; top:-47px;left:0" width="250"/>
# </a>
# <!--<![endif]-->
# </td>
# <td class="gh-td">
# </td>
# <td class="gh-td">
# </td>
# <td class="gh-td">
# <div class="gh-hide-if-nocss" id="gh-shop">
# <button aria-controls="gh-sbc-o" aria-expanded="false" class="gh-control" id="gh-shop-a">
#              Shop by category
#              <i class="gh-sprRetina" id="gh-shop-ei">
# </i>
# </button>
# <div id="gh-sbc-o">
# <h2 class="gh-ar-hdn">
#               Shop by category
#              </h2>
# </div>
# </div>
# </td>
# <td class="gh-td-s">
# <form action="https://www.ebay.com/sch/i.html" id="gh-f" method="get">
# <input name="_from" type="hidden" value="R40"/>
# <input name="_trksid" type="hidden" value="m570.l1313"/>
# <table class="gh-tbl2" role="presentation">
# <tbody>
# <tr>
# <td class="gh-td-s">
# <div id="gh-ac-box">
# <div id="gh-ac-box2">
# <label class="gh-ar-hdn" for="gh-ac">
#                    Enter your search keyword
#                   </label>
# <input aria-autocomplete="list" aria-expanded="false" aria-label="Search for anything" autocapitalize="off" autocomplete="off" autocorrect="off" class="gh-tb ui-autocomplete-input" id="gh-ac" maxlength="300" name="_nkw" placeholder="Search for anything" size="50" spellcheck="false" type="text"/>
# <input style="display:none"/>
# <script>
#                     if(document.getElementById('gh-ac').value.length !== 0) { document.getElementById('gh-ac-box').classList.add('gh-ac-box-focus'); document.getElementById('gh').classList.add('gh-sch-focus'); }
#                    </script>
# <svg aria-hidden="true" class="icon icon--search gh-search__icon" focusable="false" height="14" width="14">
# <use xlink:href="#icon-search">
# </use>
# </svg>
# </div>
# </div>
# </td>
# <td class="gh-td" id="gh-cat-td">
# <div id="gh-cat-box">
# <select aria-label="Select a category for search" class="gh-sb" id="gh-cat" name="_sacat" size="1">
# <option selected="selected" value="0">
#                    All Categories
#                   </option>
# </select>
# </div>
# </td>
# <td class="gh-td gh-sch-btn">
# <input class="btn btn-ter gh-spr" id="gh-btn" type="submit" value="Search"/>
# <svg aria-hidden="true" class="icon icon--search gh-search-btn__icon" focusable="false" height="22" width="22">
# <use xlink:href="#icon-search">
# </use>
# </svg>
# </td>
# <td class="gh-td" id="gh-as-td">
# <a _sp="m570.l2614" aria-label="Advanced Search" href="https://www.ebay.com/sch/ebayadvsearch" id="gh-as-a" title="Advanced Search">
#                  Advanced
#                 </a>
# </td>
# </tr>
# </tbody>
# </table>
# </form>
# </td>
# <td class="gh-td">
# </td>
# <td class="sticky_placeholder">
# <ul>
# </ul>
# </td>
# </tr>
# </tbody>
# </table>
# <div aria-label="Account" class="gh-hide-if-nocss" id="gh-top" role="navigation">
# <ul id="gh-topl">
# <li class="gh-t" id="gh-eb-u">
# <script>
#            (function(){try{var d=document.cookie,a=((a=d.match(/u1f[^a-zA-Z0-9]([^^]*)[0-9a-z]{8}/))?a[1].replace(/\+/g," "):"").replace(/(.{12}).*/,"$1...");if(/[<>%&'\/]/.test(a)){throw(1)}document.write("<span id=gh-ug"+(!a||/u1p.QEBfX/.test(d)?' class=gh-ug-guest>Hi! <a href="https://signin.ebay.com/ws/eBayISAPI.dll?SignIn&amp;_trksid=m570.l1524" rel="nofollow" _sp="m570.l1524">Sign in</a> <span id="gh-ug-flex">or <a href="https://reg.ebay.com/reg/PartialReg?_trksid=m570.l2621" rel="nofollow" _sp="m570.l2621">register</a></span>':' style="margin-right:3px">Hi <b>-User-</b>!'.replace(/-User-/,decodeURIComponent(escape(a))))+"</span>")}catch(b){document.write("<style>#gh-topl{display:none}</style>")}})();
#           </script>
# <noscript class="gh-t gh-spr">
#            Hi (
#            <a href="https://signin.ebay.com/ws/eBayISAPI.dll?SignIn&amp;_trksid=m570.l3348">
#             Sign in
#            </a>
#            to bid or buy)
#           </noscript>
# </li>
# <li class="gh-t gh-divider-l" id="gh-p-1">
# <a _sp="m570.l3188" class="gh-p" data-sp="m570.l3188" href="https://www.ebay.com/deals">
#            Daily Deals
#           </a>
# </li>
# <li class="gh-t gh-divider-l" id="gh-p-4">
# <a _sp="m570.l47233" class="gh-p" data-sp="m570.l47233" href="https://www.ebay.com/b/Brand-Outlet/bn_7115532402">
#            Brand Outlet
#           </a>
# </li>
# <li class="gh-t gh-divider-l" id="gh-p-3">
# <a _sp="m570.l1545" class="gh-p" data-sp="m570.l1545" href="https://ocsnext.ebay.com/ocs/home">
#            Help &amp; Contact
#           </a>
# </li>
# </ul>
# <ul id="gh-eb">
# <li class="gh-eb-li gh-t-rt gh--link__divider gh-sl-w" id="gh-p-2">
# <a _sp="m570.l1528" class="gh-p" data-sp="m570.l1528" data-treatment="SELL_LINK_WHITE_PILL" href="https://www.ebay.com/sl/sell">
#            Sell
#           </a>
# </li>
# <li class="gh-eb-li gh-margin rt" id="gh-wl-click">
# <div class="gh-menu gh--link__divider">
# <a _sp="m570.l47137" class="gh-eb-li-a gh-rvi-menu watchlist-menu" href="https://www.ebay.com/mye/myebay/watchlist" title="Watchlist">
#             Watchlist
#             <i class="gh-sprRetina gh-eb-arw gh-rvi-chevron" data-sp="m570.l47137">
# </i>
# </a>
# <a aria-expanded="false" class="gh-acc-exp-a gh-acc-a2 gh-control" data-controltarget="gh-wl-click-o" href="#gh-wl-click" role="button">
#             Expand Watch List
#            </a>
# <div aria-label="Watchlist" class="gh-sublayer gh-flyout__menu" id="gh-wl-click-flyout" role="dialog">
# <button aria-label="Close dialog" class="gh_flyout__close" id="gh-wl-click-close">
# <svg aria-hidden="true" focusable="false" height="17" width="17">
# <use xlink:href="#icon-close">
# </use>
# </svg>
# </button>
# <div id="gh-wl-click-body">
# <div class="gh-loading">
# <span aria-label="Loading" class="gh-spinner" role="img">
# </span>
# <span class="gh-state">
#                Loading...
#               </span>
# </div>
# <div class="gh-wl-click-gen-error">
# <span>
# <a href="https://signin.ebay.com/ws/eBayISAPI.dll?SignIn&amp;ru=ru">
#                 Sign in
#                </a>
#                to see your user information
#               </span>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="gh-eb-li gh-hvr gh-dd rt" data-imp="10" id="gh-eb-My">
# <div class="gh-menu">
# <a _sp="m570.l2919" class="gh-eb-li-a gh-rvi-menu" href="https://www.ebay.com/mys/home?source=GBH" title="My eBay">
#             My eBay
#             <i class="gh-sprRetina gh-eb-arw gh-rvi-chevron" data-sp="m570.l2919">
# </i>
# </a>
# <a aria-expanded="false" class="gh-acc-exp-a gh-acc-a2 gh-control" data-controltarget="gh-eb-My-o" href="#gh-eb-My" role="button">
#             Expand My eBay
#            </a>
# <div class="gh-submenu gh-eb-o" id="gh-eb-My-o">
# <ul id="gh-ul-nav" role="navigation">
# <li>
# <a _sp="m570.l1533" class="gh-eb-oa thrd" data-sp="m570.l1533" href="https://www.ebay.com/myb/Summary">
#                Summary
#               </a>
# </li>
# <li>
# <a _sp="m570.l9225" class="gh-eb-oa thrd" data-sp="m570.l9225" href="https://www.ebay.com/mye/myebay/rvi">
#                Recently Viewed
#               </a>
# </li>
# <li>
# <a _sp="m570.l1535" class="gh-eb-oa thrd" data-sp="m570.l1535" href="https://www.ebay.com/myb/BidsOffers">
#                Bids/Offers
#               </a>
# </li>
# <li>
# <a _sp="m570.l1534" class="gh-eb-oa thrd" data-sp="m570.l1534" href="https://www.ebay.com/mye/myebay/watchlist">
#                Watchlist
#               </a>
# </li>
# <li>
# <a _sp="m570.l1536" class="gh-eb-oa thrd" data-sp="m570.l1536" href="https://www.ebay.com/mye/myebay/purchase">
#                Purchase History
#               </a>
# </li>
# <li id="gh_buyagain">
# <a _sp="m570.l47010" class="gh-eb-oa thrd" data-sp="m570.l47010" href="https://www.ebay.com/mye/buyagain">
#                Buy Again
#               </a>
# </li>
# <li>
# <a _sp="m570.l1537" class="gh-eb-oa thrd" data-sp="m570.l1537" href="https://www.ebay.com/mys/home?CurrentPage=MyeBayAllSelling&amp;ssPageName=STRK:ME:LNLK:MESX&amp;source=GBH">
#                Selling
#               </a>
# </li>
# <li>
# <a _sp="m570.l9503" class="gh-eb-oa thrd" data-sp="m570.l9503" href="https://www.ebay.com/myb/SavedSearches">
#                Saved Searches
#               </a>
# </li>
# <li>
# <a _sp="m570.l9505" class="gh-eb-oa thrd" data-sp="m570.l9505" href="https://www.ebay.com/myb/SavedSellers">
#                Saved Sellers
#               </a>
# </li>
# <li>
# <a _sp="m570.l143039" class="gh-eb-oa thrd" data-sp="m570.l143039" href="https://www.ebay.com/g/mygarage">
#                My Garage
#               </a>
# </li>
# <li>
# <a _sp="m570.l1539" class="gh-eb-oa thrd" data-sp="m570.l1539" href="https://mesg.ebay.com/mesgweb/ViewMessages/0">
#                Messages
#               </a>
# </li>
# <li>
# <a _sp="m570.l105163" class="gh-eb-oa thrd" data-sp="m570.l105163" href="https://www.ebay.com/collection/hub">
#                Collection beta
#               </a>
# </li>
# <li id="gh-eb-sub-li-cpn">
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="gh-eb-li gh-hvr gh-layer rt" id="gh-eb-Alerts">
# <div class="gh-menu">
# <button aria-controls="gh-eb-Alerts-o" aria-expanded="false" class="gh-control ghn-b gh-eb-li-a">
# <i class="gh-sprRetina" id="gh-Alerts-i">
#              Notification
#             </i>
# </button>
# <div class="gh-sublayer">
# <div class="gh-eb-o" id="gh-eb-Alerts-o" style="display: none;">
# </div>
# </div>
# </div>
# </li>
# <li class="gh-eb-li gh-margin rt" id="gh-minicart-hover">
# <div class="gh-menu">
# <a _sp="m570.l2633" aria-label="Your shopping cart" class="gh-eb-li-a gh-rvi-menu" data-sp="m570.l2633" href="https://cart.ebay.com">
# <svg aria-hidden="true" class="gh-cart-icon" focusable="false">
# <use xlink:href="#icon-cart-new">
# </use>
# </svg>
# </a>
# <a aria-expanded="false" class="gh-acc-exp-a gh-acc-a2 gh-control" data-controltarget="gh-minicart-hover-o" href="#gh-minicart-hover" role="button">
#             Expand Cart
#            </a>
# <div aria-label="Your shopping cart" class="gh-sublayer gh-flyout__menu" id="gh-minicart-hover-flyout" role="dialog">
# <button aria-label="Close dialog" class="gh_flyout__close" id="gh-minicart-hover-close">
# <svg aria-hidden="true" focusable="false" height="17" width="17">
# <use xlink:href="#icon-close">
# </use>
# </svg>
# </button>
# <div id="gh-minicart-hover-body">
# <div class="gh-loading">
# <span aria-label="Loading" class="gh-spinner" role="img">
# </span>
# <span class="gh-state">
#                Loading...
#               </span>
# </div>
# <div class="gh-minicart-hover-gen-error">
# <span>
#                Something went wrong. View cart for details.
#               </span>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <input id="gh-fn-upgrade" type="hidden" value="https://c.paypal.com/da/r/efbv3.js"/>
# <div id="makeebayfaster_config" style="display:none;">
#         {"modules":["unloadOptimization","bandwidthDetection"],"unloadOptimization":{"browsers":{"Firefox":true,"Chrome":true}},"bandwidthDetection":{"url":"https://ir.ebaystatic.com/cr/v/c1/thirtysevens.jpg","maxViews":4,"imgSize":37,"expiry":300000,"timeout":250}}
#        </div>
# <div id="gh-ihelp" style="display:none;">
#         {"delay":300}
#        </div>
# <link href="https://www.ebay.com/manifest.json" rel="manifest"/>
# <!--[if lt IE 9]></div><![endif]-->
# <!--[if (gte IE 9)|!(IE)]><!-->
# </header>
# <!--<![endif]-->
# <!--ts:2022.01.03.17:24-->
# <!--rq:-->
# <!--rvr:114rcb-->
# <div class="widgets-placeholder" id="widgets-placeholder">
# </div>
# <svg hidden="" style="display: none">
# <svg height="100%" id="icon-search" viewbox="0 0 20 20" width="100%">
# <path d="M19.786 18.557l-5.093-5.093a8.1 8.1 0 0 0 1.873-5.21C16.507 3.747 12.82 0 8.254 0 3.688 0 0 3.746 0 8.254c0 4.508 3.688 8.312 8.254 8.312 2.049 0 3.863-.761 5.327-1.932l5.093 5.093a.714.714 0 0 0 .527.234c.176 0 .41-.059.527-.234.351-.351.351-.878.059-1.171l-.001.001zM1.581 8.254a6.67 6.67 0 0 1 6.673-6.673 6.67 6.67 0 0 1 6.673 6.673c0 3.688-2.985 6.732-6.673 6.732s-6.673-2.985-6.673-6.732z">
# </path>
# </svg>
# <symbol id="icon-close" viewbox="1.5 1.5 21 21">
# <path d="M22.182 3.856c.522-.554.306-1.394-.234-1.938-.54-.543-1.433-.523-1.826-.135C19.73 2.17 11.955 10 11.955 10S4.225 2.154 3.79 1.783c-.438-.371-1.277-.4-1.81.135-.533.537-.628 1.513-.25 1.938.377.424 8.166 8.218 8.166 8.218s-7.85 7.864-8.166 8.219c-.317.354-.34 1.335.25 1.805.59.47 1.24.455 1.81 0 .568-.456 8.166-7.951 8.166-7.951l8.167 7.86c.747.72 1.504.563 1.96.09.456-.471.609-1.268.1-1.804-.508-.537-8.167-8.219-8.167-8.219s7.645-7.665 8.167-8.218z">
# </path>
# </symbol>
# <svg id="gh-icon-cart" viewbox="0 0 40 32">
# <path d="M35.0390625,6.8515625 C36.4453195,6.8515625 37.4674447,7.20312148 38.1054688,7.90625 C38.7434928,8.60937852 39.0625,9.66405547 39.0625,11.0703125 L39.0625,18.9609375 C39.0625,20.2369855 38.7434928,21.226559 38.1054688,21.9296875 C37.4674447,22.632816 36.4322988,22.984375 35,22.984375 L31.484375,22.984375 C29.3749895,22.984375 27.0898561,22.9778646 24.6289063,22.9648438 C22.1679564,22.9518229 19.9349059,22.9453125 17.9296875,22.9453125 L14.921875,22.9453125 L6.8359375,4.8203125 L0.859375,4.8203125 L0.8203125,0.7578125 L8.90625,0.7578125 L12.9296875,6.8515625 L35.0390625,6.8515625 Z M34.0625,18.9609375 C34.322918,18.9609375 34.5507803,18.8632822 34.7460938,18.6679688 C34.9414072,18.4726553 35.0390625,18.2317723 35.0390625,17.9453125 C35.0390625,17.6588527 34.9414072,17.4179697 34.7460938,17.2226562 C34.5507803,17.0273428 34.322918,16.9296875 34.0625,16.9296875 L17.9296875,16.9296875 C17.6692695,16.9296875 17.4414072,17.0273428 17.2460938,17.2226562 C17.0507803,17.4179697 16.953125,17.6588527 16.953125,17.9453125 C16.953125,18.2317723 17.0507803,18.4726553 17.2460938,18.6679688 C17.4414072,18.8632822 17.6692695,18.9609375 17.9296875,18.9609375 L34.0625,18.9609375 Z M34.0625,12.90625 C34.322918,12.90625 34.5507803,12.8085947 34.7460938,12.6132812 C34.9414072,12.4179678 35.0390625,12.1770848 35.0390625,11.890625 C35.0390625,11.630207 34.9414072,11.3958344 34.7460938,11.1875 C34.5507803,10.9791656 34.322918,10.875 34.0625,10.875 L15.9375,10.875 C15.6510402,10.875 15.4101572,10.9791656 15.2148438,11.1875 C15.0195303,11.3958344 14.921875,11.630207 14.921875,11.890625 C14.921875,12.1770848 15.0195303,12.4179678 15.2148438,12.6132812 C15.4101572,12.8085947 15.6510402,12.90625 15.9375,12.90625 L34.0625,12.90625 Z M34.0234375,24.8984375 C34.8828168,24.8984375 35.6249969,25.1979137 36.25,25.796875 C36.8750031,26.3958363 37.1875,27.1249957 37.1875,27.984375 C37.1875,28.8437543 36.8750031,29.5729137 36.25,30.171875 C35.6249969,30.7708363 34.8828168,31.0703125 34.0234375,31.0703125 C33.1640582,31.0703125 32.4283885,30.7708363 31.8164062,30.171875 C31.204424,29.5729137 30.8984375,28.8437543 30.8984375,27.984375 C30.8984375,27.1249957 31.204424,26.3958363 31.8164062,25.796875 C32.4283885,25.1979137 33.1640582,24.8984375 34.0234375,24.8984375 Z M19.8828125,24.8984375 C20.7421918,24.8984375 21.4778615,25.1979137 22.0898438,25.796875 C22.701826,26.3958363 23.0078125,27.1249957 23.0078125,27.984375 C23.0078125,28.8437543 22.701826,29.5729137 22.0898438,30.171875 C21.4778615,30.7708363 20.7421918,31.0703125 19.8828125,31.0703125 C19.0234332,31.0703125 18.2877635,30.7708363 17.6757812,30.171875 C17.063799,29.5729137 16.7578125,28.8437543 16.7578125,27.984375 C16.7578125,27.1249957 17.063799,26.3958363 17.6757812,25.796875 C18.2877635,25.1979137 19.0234332,24.8984375 19.8828125,24.8984375 Z">
# </path>
# </svg>
# <symbol id="icon-check" viewbox="0 0 30 30">
# <circle cx="14.5" cy="14.5" fill="#82187c" r="14.5">
# </circle>
# <path d="M5.548 15.01l5.773 6.286L21.522 9.824" fill="#82187c" stroke="#ffffff" stroke-width="2">
# </path>
# </symbol>
# <symbol id="icon-cart-new" viewbox="0 0 23 22">
# <path d="M22 4a.999.999 0 01.97 1.242l-2 8A1 1 0 0120 14H7a1 1 0 01-.97-.758L3.22 2H1a1 1 0 110-2h3a1 1 0 01.97.758L5.78 4H22zm-1.277 2H6.28l1.5 6h11.442l1.5-6zm-4.539 12A2.995 2.995 0 0119 16a2.995 2.995 0 11-2.816 4h-5.368a3 3 0 110-2h5.368zM7 19a1 1 0 102 0 1 1 0 00-2 0zm12 1a1 1 0 110-2 1 1 0 010 2z" fill-rule="evenodd">
# </path>
# </symbol>
# </svg>
# <nav class="vi-bc-topM" role="navigation">
# <ul id="bc">
# <li class="vi-VR-bkto" id="smtBackToAnchorArrow">
# <span class="gspr vi-bkto-arrnewred">
# </span>
# </li>
# <li class="vi-VR-bkto" id="vi-brumb-frstCol">
# <a class="vi-VR-spl-lnk" href="https://www.ebay.com" id="smtBackToAnchor" title="Click to Go Back to home page">
#           Back to home page
#          </a>
# </li>
# <!--[if lt IE 8]>
# 			<li style="margin:0px 5px 0px -10px"  id="vi-VR-brumb-pipeIcon">|</li>
# 			<![endif]-->
# <li class="vi-VR-brumb-pdplnkLst" id="vi-VR-brumb-pdplnkLst">
# <div class="vi-VR-brumb-pipe-icon-wrapper">
# <span aria-hidden="true" class="vi-VR-brumb-pipe-icon">
#            |
#           </span>
#           Listed in category:
#          </div>
# </li>
# <li class="vi-VR-brumblnkLst vi-VR-brumb-hasNoPrdlnks" id="vi-VR-brumb-lnkLst">
# <ul aria-label="Listed in category:" itemscope="" itemtype="https://schema.org/BreadcrumbList" role="list">
# <li class="bc-w" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem" role="listitem">
# <a _sp="p2047675.l2706" class="thrd" href="https://www.ebay.com/b/Clothing-Shoes-Accessories-/11450" itemprop="item">
# <span itemprop="name">
#              Clothing, Shoes &amp; Accessories
#             </span>
# </a>
# <meta content="1" itemprop="position"/>
# </li>
# <li aria-hidden="true">
#            &gt;
#           </li>
# <li class="bc-w" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem" role="listitem">
# <a _sp="p2047675.l2706" class="thrd" href="https://www.ebay.com/b/Men-/260012" itemprop="item">
# <span itemprop="name">
#              Men
#             </span>
# </a>
# <meta content="2" itemprop="position"/>
# </li>
# <li aria-hidden="true">
#            &gt;
#           </li>
# <li class="bc-w" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem" role="listitem">
# <a _sp="p2047675.l2706" class="thrd" href="https://www.ebay.com/b/Mens-Clothing-/1059" itemprop="item">
# <span itemprop="name">
#              Men's Clothing
#             </span>
# </a>
# <meta content="3" itemprop="position"/>
# </li>
# <li aria-hidden="true">
#            &gt;
#           </li>
# <li class="bc-w" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem" role="listitem">
# <a _sp="p2047675.l2706" class="thrd" href="https://www.ebay.com/b/Shirts-/185100" itemprop="item">
# <span itemprop="name">
#              Shirts
#             </span>
# </a>
# <meta content="4" itemprop="position"/>
# </li>
# <li aria-hidden="true">
#            &gt;
#           </li>
# <li class="bc-w" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem" role="listitem">
# <a _sp="p2047675.l2706" class="scnd" href="https://www.ebay.com/b/T-Shirts-/15687" itemprop="item">
# <span itemprop="name">
#              T-Shirts
#             </span>
# </a>
# <meta content="5" itemprop="position"/>
# </li>
# </ul>
# </li>
# <li class="vi-share-widget-wrapper">
# <div class="vi-share-widget-rt">
# <div class="social-widget vi-share-widget-tc">
# <div class="sw">
# <a class="scIcon sw_email" data-destination="email" data-itemid="384127472200" data-language="en_US" data-spid="2047675" etafsharetitle="Data Statistics Math Computer Science Shirt Analyst T-Shirt" etafshareurl="https://www.ebay.com/itm/-/384127472200" href="javascript:;" id="sc_email" rel="nofollow">
# <span class="gh-ar-hdn">
#               Email to friends
#              </span>
# </a>
# <a class="scIcon sw_facebook" data-destination="facebook" data-tracking="" href="http://www.ebay.com/soc/share?du=https%3A%2F%2Fwww.ebay.com%2Fitm%2F-%2F384127472200&amp;rt=nc&amp;t=Data+Statistics+Math+Computer+Science+Shirt+Analyst+T-Shirt&amp;spid=2047675&amp;itm=384127472200&amp;media=http%3A%2F%2Fgalleryplus.ebayimg.com%2Fws%2Fweb%2F384127472200_1_0_1%2F1000x1000.jpg&amp;swd=2&amp;shorten=0" rel="nofollow" target="_blank">
# <span class="gh-ar-hdn">
#               Share on Facebook - opens in a new window or tab
#              </span>
# </a>
# <a class="scIcon sw_twitter" data-destination="twitter" data-tracking="" href="http://www.ebay.com/soc/share?du=https%3A%2F%2Fwww.ebay.com%2Fitm%2F-%2F384127472200&amp;rt=nc&amp;spid=2047675&amp;itm=384127472200&amp;media=http%3A%2F%2Fgalleryplus.ebayimg.com%2Fws%2Fweb%2F384127472200_1_0_1%2F1000x1000.jpg&amp;swd=3&amp;lang=en&amp;t=Check+out+Data+Statistics+Math+Computer+Science+Shirt+Analyst+T-Shirt" rel="nofollow" target="_blank">
# <span class="gh-ar-hdn">
#               Share on Twitter - opens in a new window or tab
#              </span>
# </a>
# <a class="scIcon sw_pinterest" data-destination="pinterest" data-tracking="" href="http://www.ebay.com/soc/share?du=https%3A%2F%2Fwww.ebay.com%2Fitm%2F-%2F384127472200&amp;rt=nc&amp;spid=2047675&amp;itm=384127472200&amp;media=http%3A%2F%2Fgalleryplus.ebayimg.com%2Fws%2Fweb%2F384127472200_1_0_1%2F1000x1000.jpg&amp;swd=11&amp;t=Data+Statistics+Math+Computer+Science+Shirt+Analyst+T-Shirt" rel="nofollow" target="_blank">
# <span class="gh-ar-hdn">
#               Share on Pinterest - opens in a new window or tab
#              </span>
# </a>
# </div>
# </div>
# <div class="vi-watchLink">
# <div class="watchLnk watchlink-mrg">
# <span class="watchlinkSpan" id="linkTopAct" style="display: ">
# <span>
# <a class="" href="javascript:;" id="watchLink" rel="nofollow" title="">
#                Add to Watchlist
#               </a>
# </span>
# </span>
# </div>
# <span class="vi-watch-pipe" style="display: ">
#             |
#            </span>
# </div>
# </div>
# </li>
# </ul>
# </nav>
# <div class="vi-lb-placeholder" id="scandal100938" title="ADVERTISEMENT">
# </div>
# </div>
# </div>
# </div>
# <div id="CenterPanelDF">
# <!-- CVIP Messaging Starts -->
# <!-- CVIP Messaging Ends -->
# <div class="">
# <div class="ebaylocale_en_US ebay_longlngsite" id="CenterPanel">
# <style>
#        /* PicturePanel */
# 	#PicturePanel div.img {
# 		border:1px solid #ccc;
# 		background-color:white;
# 	}
# 	/* BuyBox */
# 	.actPanel  {
# 		border-top:1px solid #ccc;
# 		border-left:1px solid #ccc;
# 		border-right:1px solid #ccc;
# 	}
# 	.watchListCmp {
# 		border-bottom:1px solid #ccc;
# 		border-left:1px solid #ccc;
# 		border-right:1px solid #ccc;
# 	}
#       </style>
# <!-- CVIP Messaging Starts -->
# <!-- CVIP Messaging Ends -->
# <div class="vi-inheritstyl" role="none">
# <div id="vi-statusmessage-panel-content">
# <div class="tmpnl">
# <div aria-atomic="true" aria-live="assertive" aria-relevant="all" class="pnl u-dspn" id="msgPanel">
# <div class="msg">
# <div class="msgPad">
# <span class="statusContent">
# <span class="statusLeftContent">
# <span class="msgTextAlign" id="w1-6-_msg">
# </span>
# </span>
# <span class="statusRightContent">
# </span>
# <div style="clear: both;">
# </div>
# </span>
# </div>
# </div>
# </div>
# <div>
# <!-- Removed welcome messages as no longer displayed -->
# <!-- CHECK if still shown on VI : Parent action Text : check how to display -->
# <!-- CHECK if still shown on VI :  -->
# <!-- IF Display Natural Search welcome message 2 is available : show that message
# 			 ELSE check if ItemTitle is available format (Item: ItemTitle) -->
# <!-- Show Variation details, VariationPrice, VariationQuantity -->
# </div>
# <div id="listingHistory">
# </div>
# <div id="otherMsg">
# </div>
# </div>
# </div>
# </div>
# <!--  Placement 100005 -->
# <link href="https://ir.ebaystatic.com/rs/c/merch-2uNIQlt_.css" rel="stylesheet" type="text/css"/>
# <div class="elf-form-captcha merchBottomHr" id="plmt_html_101224">
# <!--merch#1012240-c0-->
# <section class="merch-module merch-module--MOT">
# <div class="container_wrapper aspects-1">
# <section>
# <div class="merch-carousel__header">
# <div class="merch-carousel__title">
# <div class="merch-title-container">
# <span class="merch-title large-text-2">
# <!--F#20-->
# <!--F#19-->
# <!--F#18-->
# <!--F#0-->
# <!--F#23[0]-->
# <!--F#18-->
#                People who viewed this item also viewed
#                <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# </span>
# </div>
# </div>
# </div>
# <div aria-labelledby="carousel-status-1012240-c0-19[0[0[0]]]-14" aria-roledescription="carousel" class="carousel carousel--slides carousel--peek" role="group">
# <div class="carousel__container carousel__container--controls-disabled" id="1012240-c0-19[0[0[0]]]-14-container">
# <span aria-live="polite" class="clipped" id="carousel-status-1012240-c0-19[0[0[0]]]-14">
# <span>
#                Showing Slide 1 of 1
#               </span>
# </span>
# <button aria-describedby="carousel-status-1012240-c0-19[0[0[0]]]-14" aria-disabled="true" aria-label="Go to the previous slide, People who viewed this item also viewed" class="carousel__control carousel__control--prev" type="button">
# <svg aria-hidden="true" class="icon icon--carousel-prev" focusable="false">
# <defs>
# <symbol id="icon-carousel-prev" viewbox="0 0 8 14">
# <path d="M7.004 14a.999.999 0 01-.71-.291L.29 7.683a1.007 1.007 0 010-1.416L6.293.241a.998.998 0 011.359.053c.37.371.392.965.052 1.364L2.412 6.97l5.292 5.313c.287.286.375.717.221 1.093a1 1 0 01-.921.624z">
# </path>
# </symbol>
# </defs>
# <use xlink:href="#icon-carousel-prev">
# </use>
# </svg>
# </button>
# <div class="carousel__viewport">
# <ul class="carousel__list" id="1012240-c0-19[0[0[0]]]-14-list">
# <li class="carousel__snap-point card card-under" style="width:calc(19.607843137254903% - 12.862745098039216px);margin-right:16px;">
# <!--F#7[@0]-->
# <a _sp="p2047675.m-1.c20200818143230" class="item-tile" data-track='[{"actionKind":"NAV","operationId":"2047675","flushImmediately":false,"eventProperty":{"parentrq":"7c074689bd88de78","amdata":"amclksrc%3DITM%26aid%3D1110006%26algo%3DHOMESPLICE.SIM%26ao%3D1%26asc%3D20200818143230%26meid%3Db246ab5faf6f4f9c891500b9049450d1%26pid%3D101224%26rk%3D1%26rkt%3D5%26mehot%3Dnone%26sd%3D384127472200%26itm%3D255244762602%26pmt%3D1%26noa%3D1%26pg%3D2047675%26algv%3DDefaultOrganicWeb","ampid":"MERCH_CLK","ammiid":"b246ab5faf6f4f9c891500b9049450d1","sid":"p2047675.m-1.c20200818143230"}}]' href="https://www.ebay.com/itm/255244762602?_trkparms=amclksrc%3DITM%26aid%3D1110006%26algo%3DHOMESPLICE.SIM%26ao%3D1%26asc%3D20200818143230%26meid%3Db246ab5faf6f4f9c891500b9049450d1%26pid%3D101224%26rk%3D1%26rkt%3D5%26sd%3D384127472200%26itm%3D255244762602%26pmt%3D1%26noa%3D1%26pg%3D2047675%26algv%3DDefaultOrganicWeb&amp;_trksid=p2047675.c101224.m-1">
# <div class="item-tile__imgwrap">
# <div class="item-tile__img">
# <img alt="" class="item-img" height="225" itemprop="image" loading="eager" src="https://i.ebayimg.com/thumbs/images/g/EeYAAOSw9LBhnlvm/s-l96.jpg" width="225"/>
# </div>
# </div>
# <div class="item-info mot-item-info">
# <div class="item-info__promoted">
# </div>
# <h3 class="item-info__title clearfix">
# <!--F#20-->
# <!--F#19-->
# <!--F#18-->
# <!--F#0-->
# <!--F#23[0]-->
# <!--F#18-->
#                    3,14 Pi Number Symbol Math Science Vintage T Shirt Men Fashion 2021 Women TShirt
#                    <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# </h3>
# <div class="item-info__price mot-price clearfix">
# <!--F#20-->
# <!--F#19-->
# <!--F#18-->
# <!--F#0-->
# <!--F#23[0]-->
# <!--F#18-->
#                    $7.99
#                    <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# </div>
# <div class="item-info__discount-price mot-discount">
# </div>
# <div class="group_3_slots">
# <!--F#20-->
# <!--F#19-->
# <span class="default">
# <span aria-hidden="true">
# <!--F#16-->
# <!--F#0-->
# <!--F#23[0]-->
# <span class="sh-secondary default">
# <!--F#15-->
#                       Free shipping
#                       <!--F/-->
# <span class="clipped">
#                        Free shipping
#                       </span>
# </span>
# <!--F/-->
# <!--F/-->
# <!--F/-->
# </span>
# <span class="clipped">
#                      Free shipping
#                     </span>
# </span>
# <!--F/-->
# <!--F/-->
# </div>
# <div class="item-info__unit-price clearfix">
# </div>
# <div class="item-info__additional-price clearfix">
# </div>
# <div class="item-info__logistic-cost clearfix">
# </div>
# <div class="item-info__eek clearfix">
# </div>
# <div class="item-info__hotness clearfix">
# </div>
# <div class="item-info__eek-new-text clearfix">
# </div>
# </div>
# </a>
# <!--F/-->
# </li>
# <li class="card card-under" style="width:calc(19.607843137254903% - 12.862745098039216px);margin-right:16px;">
# <!--F#7[@1]-->
# <a _sp="p2047675.m-1.c20200818143230" class="item-tile" data-track='[{"actionKind":"NAV","operationId":"2047675","flushImmediately":false,"eventProperty":{"parentrq":"7c074689bd88de78","amdata":"amclksrc%3DITM%26aid%3D1110006%26algo%3DHOMESPLICE.SIM%26ao%3D1%26asc%3D20200818143230%26meid%3Db246ab5faf6f4f9c891500b9049450d1%26pid%3D101224%26rk%3D2%26rkt%3D5%26mehot%3Dnone%26sd%3D384127472200%26itm%3D292208555079%26pmt%3D1%26noa%3D1%26pg%3D2047675%26algv%3DDefaultOrganicWeb","ampid":"MERCH_CLK","ammiid":"b246ab5faf6f4f9c891500b9049450d1","sid":"p2047675.m-1.c20200818143230"}}]' href="https://www.ebay.com/itm/292208555079?_trkparms=amclksrc%3DITM%26aid%3D1110006%26algo%3DHOMESPLICE.SIM%26ao%3D1%26asc%3D20200818143230%26meid%3Db246ab5faf6f4f9c891500b9049450d1%26pid%3D101224%26rk%3D2%26rkt%3D5%26sd%3D384127472200%26itm%3D292208555079%26pmt%3D1%26noa%3D1%26pg%3D2047675%26algv%3DDefaultOrganicWeb&amp;_trksid=p2047675.c101224.m-1">
# <div class="item-tile__imgwrap">
# <div class="item-tile__img">
# <img alt="" class="item-img" height="225" itemprop="image" loading="eager" src="https://i.ebayimg.com/thumbs/images/g/DRcAAOSwuwNZilr9/s-l96.jpg" width="225"/>
# </div>
# </div>
# <div class="item-info mot-item-info">
# <div class="item-info__promoted">
# </div>
# <h3 class="item-info__title clearfix">
# <!--F#20-->
# <!--F#19-->
# <!--F#18-->
# <!--F#0-->
# <!--F#23[0]-->
# <!--F#18-->
#                    Nerd Life T Shirt Geekery Geek Nerdy Dork Computer Data Science Math Physics Tee
#                    <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# </h3>
# <div class="item-info__price mot-price clearfix">
# <!--F#20-->
# <!--F#19-->
# <!--F#18-->
# <!--F#0-->
# <!--F#23[0]-->
# <!--F#18-->
#                    $15.99
#                    <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# </div>
# <div class="item-info__discount-price mot-discount">
# </div>
# <div class="group_3_slots">
# <!--F#20-->
# <!--F#19-->
# <span class="default">
# <span aria-hidden="true">
# <!--F#16-->
# <!--F#0-->
# <!--F#23[0]-->
# <span class="sh-secondary default">
# <!--F#15-->
#                       + $5.95 shipping
#                       <!--F/-->
# <span class="clipped">
#                        + $5.95 shipping
#                       </span>
# </span>
# <!--F/-->
# <!--F/-->
# <!--F/-->
# </span>
# <span class="clipped">
#                      + $5.95 shipping
#                     </span>
# </span>
# <!--F/-->
# <!--F/-->
# </div>
# <div class="item-info__unit-price clearfix">
# </div>
# <div class="item-info__additional-price clearfix">
# </div>
# <div class="item-info__logistic-cost clearfix">
# </div>
# <div class="item-info__eek clearfix">
# </div>
# <div class="item-info__hotness clearfix">
# </div>
# <div class="item-info__eek-new-text clearfix">
# </div>
# </div>
# </a>
# <!--F/-->
# </li>
# <li class="card card-under" style="width:calc(19.607843137254903% - 12.862745098039216px);margin-right:16px;">
# <!--F#7[@2]-->
# <a _sp="p2047675.m-1.c20200818143230" class="item-tile" data-track='[{"actionKind":"NAV","operationId":"2047675","flushImmediately":false,"eventProperty":{"parentrq":"7c074689bd88de78","amdata":"amclksrc%3DITM%26aid%3D1110006%26algo%3DHOMESPLICE.SIM%26ao%3D1%26asc%3D20200818143230%26meid%3Db246ab5faf6f4f9c891500b9049450d1%26pid%3D101224%26rk%3D3%26rkt%3D5%26mehot%3Dnone%26sd%3D384127472200%26itm%3D124379872296%26pmt%3D1%26noa%3D1%26pg%3D2047675%26algv%3DDefaultOrganicWeb","ampid":"MERCH_CLK","ammiid":"b246ab5faf6f4f9c891500b9049450d1","sid":"p2047675.m-1.c20200818143230"}}]' href="https://www.ebay.com/itm/124379872296?_trkparms=amclksrc%3DITM%26aid%3D1110006%26algo%3DHOMESPLICE.SIM%26ao%3D1%26asc%3D20200818143230%26meid%3Db246ab5faf6f4f9c891500b9049450d1%26pid%3D101224%26rk%3D3%26rkt%3D5%26sd%3D384127472200%26itm%3D124379872296%26pmt%3D1%26noa%3D1%26pg%3D2047675%26algv%3DDefaultOrganicWeb&amp;_trksid=p2047675.c101224.m-1">
# <div class="item-tile__imgwrap">
# <div class="item-tile__img">
# <img alt="" class="item-img" height="225" itemprop="image" loading="eager" src="https://i.ebayimg.com/thumbs/images/g/948AAOSwGMVfg6lL/s-l96.jpg" width="225"/>
# </div>
# </div>
# <div class="item-info mot-item-info">
# <div class="item-info__promoted">
# </div>
# <h3 class="item-info__title clearfix">
# <!--F#20-->
# <!--F#19-->
# <!--F#18-->
# <!--F#0-->
# <!--F#23[0]-->
# <!--F#18-->
#                    Data Analyst Gifts, Data Scientist Shirt, Programmer Gifts,  T-shirt
#                    <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# </h3>
# <div class="item-info__price mot-price clearfix">
# <!--F#20-->
# <!--F#19-->
# <!--F#18-->
# <!--F#0-->
# <!--F#23[0]-->
# <!--F#18-->
#                    $18.99
#                    <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# </div>
# <div class="item-info__discount-price mot-discount">
# </div>
# <div class="group_3_slots">
# <!--F#20-->
# <!--F#19-->
# <span class="default">
# <span aria-hidden="true">
# <!--F#16-->
# <!--F#0-->
# <!--F#23[0]-->
# <span class="sh-secondary default">
# <!--F#15-->
#                       + $2.99 shipping
#                       <!--F/-->
# <span class="clipped">
#                        + $2.99 shipping
#                       </span>
# </span>
# <!--F/-->
# <!--F/-->
# <!--F/-->
# </span>
# <span class="clipped">
#                      + $2.99 shipping
#                     </span>
# </span>
# <!--F/-->
# <!--F/-->
# </div>
# <div class="item-info__unit-price clearfix">
# </div>
# <div class="item-info__additional-price clearfix">
# </div>
# <div class="item-info__logistic-cost clearfix">
# </div>
# <div class="item-info__eek clearfix">
# </div>
# <div class="item-info__hotness clearfix">
# </div>
# <div class="item-info__eek-new-text clearfix">
# </div>
# </div>
# </a>
# <!--F/-->
# </li>
# <li class="card card-under" style="width:calc(19.607843137254903% - 12.862745098039216px);margin-right:16px;">
# <!--F#7[@3]-->
# <a _sp="p2047675.m-1.c20200818143230" class="item-tile" data-track='[{"actionKind":"NAV","operationId":"2047675","flushImmediately":false,"eventProperty":{"parentrq":"7c074689bd88de78","amdata":"amclksrc%3DITM%26aid%3D1110006%26algo%3DHOMESPLICE.SIM%26ao%3D1%26asc%3D20200818143230%26meid%3Db246ab5faf6f4f9c891500b9049450d1%26pid%3D101224%26rk%3D4%26rkt%3D5%26mehot%3Dnone%26sd%3D384127472200%26itm%3D293221412747%26pmt%3D0%26noa%3D1%26pg%3D2047675%26algv%3DDefaultOrganicWeb","ampid":"MERCH_CLK","ammiid":"b246ab5faf6f4f9c891500b9049450d1","sid":"p2047675.m-1.c20200818143230"}}]' href="https://www.ebay.com/itm/293221412747?_trkparms=amclksrc%3DITM%26aid%3D1110006%26algo%3DHOMESPLICE.SIM%26ao%3D1%26asc%3D20200818143230%26meid%3Db246ab5faf6f4f9c891500b9049450d1%26pid%3D101224%26rk%3D4%26rkt%3D5%26sd%3D384127472200%26itm%3D293221412747%26pmt%3D0%26noa%3D1%26pg%3D2047675%26algv%3DDefaultOrganicWeb&amp;_trksid=p2047675.c101224.m-1">
# <div class="item-tile__imgwrap">
# <div class="item-tile__img">
# <img alt="" class="item-img" height="225" itemprop="image" loading="eager" src="https://i.ebayimg.com/thumbs/images/g/~4MAAOSwIJVhqQW-/s-l96.jpg" width="225"/>
# </div>
# </div>
# <div class="item-info mot-item-info">
# <div class="item-info__promoted">
# </div>
# <h3 class="item-info__title clearfix">
# <!--F#20-->
# <!--F#19-->
# <!--F#18-->
# <!--F#0-->
# <!--F#23[0]-->
# <!--F#18-->
#                    Mens String Theory Tshirt Funny Cat Math Science Nerdy Tee
#                    <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# </h3>
# <div class="item-info__price mot-price clearfix">
# <!--F#20-->
# <!--F#19-->
# <!--F#18-->
# <!--F#0-->
# <!--F#23[0]-->
# <!--F#18-->
#                    $9.59
#                    <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# </div>
# <div class="item-info__discount-price mot-discount">
# </div>
# <div class="group_3_slots">
# <!--F#20-->
# <!--F#19-->
# <span class="default">
# <span aria-hidden="true">
# <!--F#16-->
# <!--F#0-->
# <!--F#23[0]-->
# <span class="sh-secondary default">
# <!--F#15-->
#                       Free shipping
#                       <!--F/-->
# <span class="clipped">
#                        Free shipping
#                       </span>
# </span>
# <!--F/-->
# <!--F/-->
# <!--F/-->
# </span>
# <span class="clipped">
#                      Free shipping
#                     </span>
# </span>
# <!--F/-->
# <!--F/-->
# </div>
# <div class="item-info__unit-price clearfix">
# </div>
# <div class="item-info__additional-price clearfix">
# </div>
# <div class="item-info__logistic-cost clearfix">
# </div>
# <div class="item-info__eek clearfix">
# </div>
# <div class="item-info__hotness clearfix">
# </div>
# <div class="item-info__eek-new-text clearfix">
# </div>
# </div>
# </a>
# <!--F/-->
# </li>
# <li class="card card-under" style="width:calc(19.607843137254903% - 12.862745098039216px);margin-right:false;">
# <!--F#7[@4]-->
# <a _sp="p2047675.m-1.c20200818143230" class="item-tile" data-track='[{"actionKind":"NAV","operationId":"2047675","flushImmediately":false,"eventProperty":{"parentrq":"7c074689bd88de78","amdata":"amclksrc%3DITM%26aid%3D1110006%26algo%3DHOMESPLICE.SIM%26ao%3D1%26asc%3D20200818143230%26meid%3Db246ab5faf6f4f9c891500b9049450d1%26pid%3D101224%26rk%3D5%26rkt%3D5%26mehot%3Dnone%26sd%3D384127472200%26itm%3D224765353543%26pmt%3D1%26noa%3D1%26pg%3D2047675%26algv%3DDefaultOrganicWeb","ampid":"MERCH_CLK","ammiid":"b246ab5faf6f4f9c891500b9049450d1","sid":"p2047675.m-1.c20200818143230"}}]' href="https://www.ebay.com/itm/224765353543?_trkparms=amclksrc%3DITM%26aid%3D1110006%26algo%3DHOMESPLICE.SIM%26ao%3D1%26asc%3D20200818143230%26meid%3Db246ab5faf6f4f9c891500b9049450d1%26pid%3D101224%26rk%3D5%26rkt%3D5%26sd%3D384127472200%26itm%3D224765353543%26pmt%3D1%26noa%3D1%26pg%3D2047675%26algv%3DDefaultOrganicWeb&amp;_trksid=p2047675.c101224.m-1">
# <div class="item-tile__imgwrap">
# <div class="item-tile__img">
# <img alt="" class="item-img" height="225" itemprop="image" loading="eager" src="https://i.ebayimg.com/thumbs/images/g/qrIAAOSwNTRhzMZ1/s-l96.jpg" width="225"/>
# </div>
# </div>
# <div class="item-info mot-item-info">
# <div class="item-info__promoted">
# </div>
# <h3 class="item-info__title clearfix">
# <!--F#20-->
# <!--F#19-->
# <!--F#18-->
# <!--F#0-->
# <!--F#23[0]-->
# <!--F#18-->
#                    Nike Mens Athletic Cut 2XL Shirt- Math/Science Themed-Perfect Condition
#                    <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# <!--F/-->
# </h3>
# <div class="item-info__price mot-price clearfix">
# <!--F#20-->
# <!--F#19-->
# <!--F#18-->
# <!--F#0-->
# <!--F#23[0]-->
# <!--F#18-->
#                    $13.00
#                    <!--F/-->
# ...
#    </script>
# <script>
#     $vim_C=(window.$vim_C||[]).concat({"p":"FOLLOW_EBAY_HELPER","g":{"isSEOMacroDataEnabled":true},"w":[["FOLLOW_EBAY_HELPER0-0",0,{"id":"follow-ebay-helper","showCurrent":true,"prefix":"fol","csrf":"aa2aa805dc36f68966faf3f6eb642b2ff2d4194b277dd85bd9268f3231b8f7e9"}]],"t":["/@ebay/follow-helper$1.1.0/src/components/follow-helper/component-browser"]})
#    </script>
# <script>
#     $vim_C=(window.$vim_C||[]).concat({"p":"PAYMENTS_ATF_SECTION_MODULE","g":{"isSEOMacroDataEnabled":true},"w":[["PAYMENTS_ATF_SECTION_MODULE0-0",0,{"model":{"_type":"LayoutSectionModule","sectionLayout":{"LIST_1_COLUMN":["payments","financing","cobranded","escrow"]},"sections":{"cobranded":{"_type":"LayoutSection","dataItemLayout":{"LIST_1_COLUMN":["ebay_cobranded"]},"dataItems":{"ebay_cobranded":{"_type":"LabelsValues","values":[{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","accessibilityText":"eBay Mastercard","icon":"EBAY_COBRANDED_ATF"}]},{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Earn up to 5x points when you use your eBay Mastercard®."},{"_type":"TextSpan","text":" "},{"_type":"TextSpan","text":"Learn more","action":{"_type":"Action","URL":"https://pages.ebay.com/creditcard","type":"NAV","name":"COBRANDED_LEARN_MORE","clientPresentationMetadata":{"presentationType":"OPEN_WINDOW"},"trackingList":[{"eventFamily":"ITM","eventAction":"ACTN","actionKind":"CLICK","operationId":"2047675","flushImmediately":false,"eventProperty":{"parentrq":"7c074689bd88de78","pageci":"52bf4283-ff5a-4bf1-8825-1669605698c4","moduledtl":"mi:141243|li:47940","sid":"p2047675.m141243.l47940"}}]}}]}]}}},"payments":{"_type":"LayoutSection","dataItemLayout":{"LIST_1_COLUMN":["payments","deposits"]},"dataItems":{"payments":{"_type":"LabelsValues","labels":[{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Payments:"}]}],"values":[{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","accessibilityText":"PayPal","icon":"PAYPAL"},{"_type":"TextSpan","text":" "},{"_type":"TextSpan","accessibilityText":"Google Pay","icon":"GOOGLE_PAY"},{"_type":"TextSpan","text":" "},{"_type":"TextSpan","accessibilityText":"Visa","icon":"VISA"},{"_type":"TextSpan","text":" "},{"_type":"TextSpan","accessibilityText":"Master Card","icon":"MASTER_CARD"},{"_type":"TextSpan","text":" "},{"_type":"TextSpan","accessibilityText":"American Express","icon":"AM_EX"},{"_type":"TextSpan","text":" "},{"_type":"TextSpan","accessibilityText":"Discover","icon":"DISCOVER"}]}]}}},"financing":{"_type":"LayoutSection","dataItemLayout":{"LIST_1_COLUMN":["paypalCredit_us","paypalCredit_uk","afterpay_au","klarna_de"]},"dataItems":{"paypalCredit_us":{"_type":"LabelsValues","values":[{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","accessibilityText":"Paypal Credit","icon":"PAYPAL_CREDIT_ATF_US"}]},{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Special financing available. | "},{"_type":"TextSpan","text":"See terms and apply now","styles":["PSEUDOLINK"],"action":{"_type":"Action","URL":"https://creditapply.paypal.com/apply?guid=VO3U2L3R&assetId=coreofferA","type":"NAV","name":"FINANCING_ATF","clientPresentationMetadata":{"presentationType":"OPEN_WINDOW"},"trackingList":[{"eventFamily":"ITM","eventAction":"ACTN","actionKind":"CLICK","operationId":"2047675","flushImmediately":false,"eventProperty":{"parentrq":"7c074689bd88de78","pageci":"52bf4283-ff5a-4bf1-8825-1669605698c4","moduledtl":"mi:141243|li:46286","sid":"p2047675.m141243.l46286"}}]},"accessibilityText":"See terms and apply now for PayPal Credit - opens in a new window or tab"}]}]}}}},"meta":{"name":"PAYMENTS_ATF_SECTION_MODULE","trackingList":[{"eventFamily":"ITM","eventAction":"VIEW","operationId":"2047675","flushImmediately":false,"eventProperty":{"moduledtl":"mi:2547"}}]}}},{"f":1}]],"t":["/@ebay/ux-app$2.13.7/components/d-payments-minview/index.marko"]})
#    </script>
# <script>
#     $vim_C=(window.$vim_C||[]).concat({"p":"SEO_LINKING","g":{"isSEOMacroDataEnabled":true},"w":[["SEO_LINKING0-0",0,{"model":{"_type":"NAVIGATIONS_LIST","meta":{"name":"SEO_LINKING","trackingList":[{"eventFamily":"ITM","eventAction":"VIEW","operationId":"2047675","flushImmediately":false,"eventProperty":{"moduledtl":"mi:2547"}}]},"containers":[{"_type":"CardContainer","cards":[{"_type":"NavigationCard","title":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"T-Shirt T-Shirts for Men"},{"_type":"TextSpan","text":","}]},"image":{"_type":"Image","title":"T-Shirt T-Shirts for Men","URL":"https://i.ebayimg.com/00/s/NTAwWDQ5OQ==/z/4WIAAOSwuDFchlwT/$_26.JPG","originalSize":{"height":140,"width":140}},"action":{"_type":"Action","URL":"https://www.ebay.com/b/T-Shirt-T-Shirts-for-Men/15687/bn_7116517929","type":"NAV","trackingList":[{"actionKind":"NAV","operationId":"2047675","flushImmediately":false,"eventProperty":{"sid":"p2047675.m2547.l88903.c0"}},{"eventFamily":"ITM","eventAction":"ACTN","actionKind":"CLICK","operationId":"2047675","flushImmediately":false,"eventProperty":{"moduledtl":"mi:2547|li:88903","sid":"p2047675.m2547.l88903.c0"}}]}},{"_type":"NavigationCard","title":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Men's T-Shirts"},{"_type":"TextSpan","text":","}]},"image":{"_type":"Image","title":"Men's T-Shirts","URL":"https://i.ebayimg.com/images/g/U4IAAOSwvFtekuNV/s-l140.jpg","originalSize":{"height":140,"width":140}},"action":{"_type":"Action","URL":"https://www.ebay.com/b/Mens-T-Shirts/15687/bn_704987","type":"NAV","trackingList":[{"actionKind":"NAV","operationId":"2047675","flushImmediately":false,"eventProperty":{"sid":"p2047675.m2547.l88903.c1"}},{"eventFamily":"ITM","eventAction":"ACTN","actionKind":"CLICK","operationId":"2047675","flushImmediately":false,"eventProperty":{"moduledtl":"mi:2547|li:88903","sid":"p2047675.m2547.l88903.c1"}}]}},{"_type":"NavigationCard","title":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"T T T-Shirts for Men"},{"_type":"TextSpan","text":","}]},"image":{"_type":"Image","title":"T T T-Shirts for Men","URL":"https://i.ebayimg.com/images/g/EUgAAOSw9fZeMUam/s-l140.jpg","originalSize":{"height":140,"width":140}},"action":{"_type":"Action","URL":"https://www.ebay.com/b/T-T-T-Shirts-for-Men/15687/bn_7116493931","type":"NAV","trackingList":[{"actionKind":"NAV","operationId":"2047675","flushImmediately":false,"eventProperty":{"sid":"p2047675.m2547.l88903.c2"}},{"eventFamily":"ITM","eventAction":"ACTN","actionKind":"CLICK","operationId":"2047675","flushImmediately":false,"eventProperty":{"moduledtl":"mi:2547|li:88903","sid":"p2047675.m2547.l88903.c2"}}]}},{"_type":"NavigationCard","title":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"T-Shirts for Women"},{"_type":"TextSpan","text":","}]},"image":{"_type":"Image","title":"T-Shirts for Women","URL":"https://i.ebayimg.com/images/g/HI0AAOSwFbFdVLFz/s-l140.jpg","originalSize":{"height":140,"width":140}},"action":{"_type":"Action","URL":"https://www.ebay.com/b/T-Shirts-for-Women/53159/bn_96630496","type":"NAV","trackingList":[{"actionKind":"NAV","operationId":"2047675","flushImmediately":false,"eventProperty":{"sid":"p2047675.m2547.l88903.c3"}},{"eventFamily":"ITM","eventAction":"ACTN","actionKind":"CLICK","operationId":"2047675","flushImmediately":false,"eventProperty":{"moduledtl":"mi:2547|li:88903","sid":"p2047675.m2547.l88903.c3"}}]}},{"_type":"NavigationCard","title":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Boys' Tops, Shirts & T-Shirts"},{"_type":"TextSpan","text":","}]},"image":{"_type":"Image","title":"Boys' Tops, Shirts & T-Shirts","URL":"https://i.ebayimg.com/images/g/oBEAAOSwnltffbeX/s-l140.jpg","originalSize":{"height":140,"width":140}},"action":{"_type":"Action","URL":"https://www.ebay.com/b/Boys-Tops-Shirts-T-Shirts/260966/bn_7117575233","type":"NAV","trackingList":[{"actionKind":"NAV","operationId":"2047675","flushImmediately":false, ...
#    </script>
# <script>
#     $vim_C=(window.$vim_C||[]).concat({"p":"RETURNS_ATF_SECTION_MODULE","g":{"isSEOMacroDataEnabled":true},"w":[["RETURNS_ATF_SECTION_MODULE0-0",0,{"model":{"_type":"LayoutSectionModule","sectionLayout":{"LIST_1_COLUMN":["returns"]},"sections":{"returns":{"_type":"LayoutSection","dataItemLayout":{"LIST_1_COLUMN":["returns"]},"dataItems":{"returns":{"_type":"LabelsValues","labels":[{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Returns:"}]}],"values":[{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Seller does not accept returns"},{"_type":"TextSpan","text":" | "},{"_type":"TextSpan","text":"See details","styles":["SECONDARY"],"action":{"_type":"Action","type":"OPERATION","clientPresentationMetadata":{"operationIdentifier":"SEE_DETAILS_RETURNS_ATF_SECTION_MODULE","presentationType":"SCROLL_TO","moduleKey":"RETURNS_SECTION_MODULE"},"trackingList":[{"eventFamily":"ITM","eventAction":"ACTN","actionKind":"CLICK","operationId":"2047675","flushImmediately":false,"eventProperty":{"parentrq":"7c074689bd88de78","pageci":"52bf4283-ff5a-4bf1-8825-1669605698c4","moduledtl":"mi:2547|li:2574","sid":"p2047675.m2547.l2574"}}]}}]}]}}}},"meta":{"name":"RETURNS_ATF_SECTION_MODULE","trackingList":[{"eventFamily":"ITM","eventAction":"VIEW","operationId":"2047675","flushImmediately":false,"eventProperty":{"moduledtl":"mi:2547"}}]}}},{"f":1}]],"t":["/@ebay/ux-app$2.13.7/components/x-returns-minview/index.marko"]})
#    </script>
# <!-- Pulsar Tracking setup - store tracking events in _plsUBTTQ before we have to load PulsarUBT.js -->
# <script type="text/javascript">
#     var _plsUBTTQ = [];
#         var _plsubtInp = {"eventFamily": "ITM", "samplingRate": 100, "disableImp": true, "pageId": 2047675, "app": "viewitem"};
#         function addPulsarEvent(event) { _plsUBTTQ.push(event); }
#         function getPulsarEvents() { return _plsUBTTQ; }
#
#         // On window load, check to see if PulsarUBT.js is already on the page somewhere
#         // if not, create a script element and load it ourselves.
#         window.addEventListener('load', function() {
#             var pulsarScriptSrc = "https://ir.ebaystatic.com/rs/v/s0hteylevy4bpkd12dvkd4yi5ms.js";
#             var pulsarScriptTagExists = isResourceAlreadyAttached(pulsarScriptSrc, "script", "src");
#
#             if (!pulsarScriptTagExists) {
#                 var scriptTag = document.createElement("script");
#                 scriptTag.setAttribute("type", "text/javascript");
#                 scriptTag.setAttribute("src", pulsarScriptSrc);
#                 document.getElementsByTagName('body')[0].appendChild(scriptTag);
#             }
#         });
#
#         function isResourceAlreadyAttached(url,tagType, attribute) {
#             if (!url)
#                 return;
#
#             var resources = document.getElementsByTagName(tagType);
#             for (var i = resources.length - 1; i >= 0; i--) {
#                 if (resources[i][attribute] === url)
#                     return true;
#             }
#             return false;
#         }
#    </script>
# </div>
# <!-- RcmdId ViewItemPageRaptor,RlogId t6ulcpjqcj9%3Fjqpsobtlrbn%28ktw3v*w%60ut3530-17e266e6071-0x160 -->
# <!-- RcmdId ViewItemPageRaptor,RlogId t6ulcpjqcj9%3Fjqpsobtlrbn%28ktw3v*w%60ut3530-17e266e6071-0x160 -->
# <!-- SiteId: 0, Environment: production, AppName: viewitem, PageId: 2047675 -->
# <script>
#    var rlogId = "t6ulcpjqcj9%3Fjqpsobtlrbn%28ktw3v*w%60ut3530-17e266e6071-0x160";
#   </script>
# <script id="worker1" type="javascript/worker">
#    self.onmessage = function(e) {
# 						var request = e.data;
# 						if(request && request.type && request.type =="request"){
# 							doAjaxCall(request.url);
# 						}
#     				};
#
# 					function getXMLHttpClient(){
#     					var xmlhttp=null;
#      					try {
#          					xmlhttp = new XMLHttpRequest();
#      					}catch (e) {
#           					var XMLHTTP_IDS = new Array('MSXML2.XMLHTTP.5.0',
#                                     'MSXML2.XMLHTTP.4.0',
#                                     'MSXML2.XMLHTTP.3.0',
#                                     'MSXML2.XMLHTTP',
#                                     'Microsoft.XMLHTTP' );
#          					for (var i=0;i < XMLHTTP_IDS.length && !success; i++) {
#              					try {
#                   					xmlhttp = new ActiveXObject(XMLHTTP_IDS[i]);
#                					} catch (e) {}
#          					}
#                    		}
#                   		return xmlhttp;
# 				  	}
#
#
# 					function doAjaxCall(url){
# 						var xhttp = getXMLHttpClient();
#          				xhttp.onreadystatechange = function() {
#          					if (xhttp.readyState == 4) {
# 								if( xhttp.status == 200){
# 									self.postMessage({'type':'response','response': xhttp.responseText});
# 								}else{
# 									self.postMessage({'type':'response','response': xhttp.status});
# 			 					}
#         	 				}
#   		  				};
#   					xhttp.open("GET", url, true);
# 					if(false){
# 					xhttp.setRequestHeader('X-EBAY-VI-PREFETCH2', 'true');
# 					}else{
# 					xhttp.setRequestHeader('X-EBAY-VI-PREFETCH', 'true');
# 					}
#  					xhttp.send('');
# 					}
#   </script>
# <script>
#    function prefetchMerch(){
# 	    	  var viUrls=[];
# 			  if(false){
# 				  if(window.localStorage){
# 					  try{
# 						  var arrStr = window.localStorage.getItem("VIUrls");
# 						  if(arrStr){
# 							viUrls = JSON.parse(arrStr);
# 						  }
# 					  }catch(err){
# 					  }
# 				  }
# 			  }else if(true){
# 				  viUrls = $(""+function(){var x = [];$('#merch_html_100623 div.mfe-reco-flat-cell-text>a.mfe-reco-link, #merch_html_100005 a.mfe-reco-link').filter(function(idx){if(idx < 3 && $(this).attr('href') && $(this).attr('href').indexOf('/itm/') != -1){ $(this).attr('id', 'pf_'+idx);x.push('#pf_'+idx); return}});return x.join(',');}()+"").map(function(idx) {
# 				        var href = this.href;
# 				        if(href && (href.indexOf('/itm')!=-1 && href.indexOf('/itm')<50)){
# 				        	 $(this).attr('data-trk', idx);
# 							 return href;
# 				        }
# 				  });
# 			  }
# 			  var textContent = document.querySelector('#worker1').textContent;
# 			  function createWorker(){
# 			    	var blob = new Blob([textContent]);
# 			    	var worker = new Worker(window.URL.createObjectURL(blob));
# 			    	return worker;
# 			    }
# 				if(viUrls && viUrls.length > 0){
# 					var prefetchMaxVal = 3;
# 					if(viUrls.length < prefetchMaxVal){
# 						prefetchMaxVal=viUrls.length;
# 					}
# 					for(var i=0;i<prefetchMaxVal;i++){
# 						 var worker = createWorker();
# 						 worker.postMessage({'type':'request','url':viUrls[i]});
# 						 worker.onmessage = function(e) {
# 							 var response = e.data;
# 							 if(response && response.type && response.type =="response"){
# 							 }
# 						 };
# 					}
# 					$('ul.mfe-recos').on('click', 'a', function(){
# 						  var id =  $(this).attr('data-trk');
# 						  $(document).trigger('rover', {'sid':'p2047675.l8531', 'mclk': id});
# 					});
# 				}
#
# 	      };
# 	      $(window).load(function(){
# 	    	  prefetchMerch();
# 	      });
#   </script>
# </body>
# </html>
# <img src="https://rover.ebay.com/roversync/?site=0&amp;stg=1&amp;mpt=1641322274927"/>

# %%
#get Title
title = soup2.find(id='itemTitle').get_text()
print(title)
# Out:
#              Details about
#
#             Data Statistics Math Computer Science Shirt Analyst T-Shirt

# %%
#get Price
price = soup2.find(id ='mm-saleDscPrc').get_text()
print(price)
# Out:
#                       US $13.29

# %%
price = price.split('$')[1].strip()
title = title.split('about')[1].strip()

print(price)
print(title)
# Out:
# 13.29
# Data Statistics Math Computer Science Shirt Analyst T-Shirt

# %%
# Out:
# 'Data Statistics Math Computer Science Shirt Analyst T-Shirt'

# %%
today = datetime.date.today()
print(today)
# Out:
# 2022-01-04

# %%
#Create dataset with price and title in Excel
header = ['Title', 'Price','Date']
data = [title, price, today]

with open('EbayWebScraperDataset.csv','w', newline='', encoding = 'UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
df = pd.read_csv(r'C:\Users\fabip\EbayWebScraperDataset.csv')
df
# Out:
#                                                Title  Price        Date
# 0  Data Statistics Math Computer Science Shirt An...  13.29  2022-01-04

# %%
#Appending data to csv
with open('EbayWebScraperDataset.csv','a+', newline='', encoding = 'UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
def check_price():
    URL = 'https://www.ebay.com/itm/384127472200?hash=item596fc81248:g:kCoAAOSwF05gjBu0'

    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36"}

    page = requests.get(URL, headers= headers)
    
    soup1 = BeautifulSoup(page.content, 'html.parser')

    soup2 = BeautifulSoup(soup1.prettify(),'html.parser')
    
    title = soup2.find(id='itemTitle').get_text()
    
    price = soup2.find(id ='mm-saleDscPrc').get_text()
    
    price = price.split('$')[1].strip()
    
    title = title.split('about')[1].strip()
    
    today = datetime.date.today()
    
    header = ['Title', 'Price','Date']
    data = [title, price, today]
    
    with open('EbayWebScraperDataset.csv','a+', newline='', encoding = 'UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)
    
    if(price < 14):
        send_mail()

# %%
while(True):
    check_price()
    time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-9d49b55d09d0> in <module>
#       1 while(True):
#       2     check_price()
# ----> 3     time.sleep(5)
#
# KeyboardInterrupt:

# %%
df = pd.read_csv(r'C:\Users\fabip\EbayWebScraperDataset.csv')
df
# Out:
#                                                 Title  Price        Date
# 0   Data Statistics Math Computer Science Shirt An...  13.29  2022-01-04
# 1   Data Statistics Math Computer Science Shirt An...  13.29  2022-01-04
# 2   Data Statistics Math Computer Science Shirt An...  13.29  2022-01-04
# 3   Data Statistics Math Computer Science Shirt An...  13.29  2022-01-04
# 4   Data Statistics Math Computer Science Shirt An...  13.29  2022-01-04
# 5   Data Statistics Math Computer Science Shirt An...  13.29  2022-01-04
# 6   Data Statistics Math Computer Science Shirt An...  13.29  2022-01-04
# 7   Data Statistics Math Computer Science Shirt An...  13.29  2022-01-04
# 8   Data Statistics Math Computer Science Shirt An...  13.29  2022-01-04
# 9   Data Statistics Math Computer Science Shirt An...  13.29  2022-01-04
# 10  Data Statistics Math Computer Science Shirt An...  13.29  2022-01-04
# 11  Data Statistics Math Computer Science Shirt An...  13.29  2022-01-04
# 12  Data Statistics Math Computer Science Shirt An...  13.29  2022-01-04
# 13  Data Statistics Math Computer Science Shirt An...  13.29  2022-01-04
# 14  Data Statistics Math Computer Science Shirt An...  13.29  2022-01-04
# 15  Data Statistics Math Computer Science Shirt An...  13.29  2022-01-04
# 16  Data Statistics Math Computer Science Shirt An...  13.29  2022-01-04
# 17  Data Statistics Math Computer Science Shirt An...  13.29  2022-01-04
# 18  Data Statistics Math Computer Science Shirt An...  13.29  2022-01-04

# %%
def send_mail():
    server =
